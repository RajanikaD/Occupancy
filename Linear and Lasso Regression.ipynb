# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv(r"C:\Users\rajan\Downloads\occupancy_data\datatraining.txt")

# %%
data
# Out:
#                      date  Temperature  Humidity  Light         CO2  \
# 1     2015-02-04 17:51:00        23.18   27.2720  426.0  721.250000
# 2     2015-02-04 17:51:59        23.15   27.2675  429.5  714.000000
# 3     2015-02-04 17:53:00        23.15   27.2450  426.0  713.500000
# 4     2015-02-04 17:54:00        23.15   27.2000  426.0  708.250000
# 5     2015-02-04 17:55:00        23.10   27.2000  426.0  704.500000
# ...                   ...          ...       ...    ...         ...
# 8139  2015-02-10 09:29:00        21.05   36.0975  433.0  787.250000
# 8140  2015-02-10 09:29:59        21.05   35.9950  433.0  789.500000
# 8141  2015-02-10 09:30:59        21.10   36.0950  433.0  798.500000
# 8142  2015-02-10 09:32:00        21.10   36.2600  433.0  820.333333
# 8143  2015-02-10 09:33:00        21.10   36.2000  447.0  821.000000
#
#       HumidityRatio  Occupancy
# 1          0.004793          1
# 2          0.004783          1
# 3          0.004779          1
# ...

# %%
df=data.iloc[:, 1:7]

# %%
df
# Out:
#       Temperature  Humidity  Light         CO2  HumidityRatio  Occupancy
# 1           23.18   27.2720  426.0  721.250000       0.004793          1
# 2           23.15   27.2675  429.5  714.000000       0.004783          1
# 3           23.15   27.2450  426.0  713.500000       0.004779          1
# 4           23.15   27.2000  426.0  708.250000       0.004772          1
# 5           23.10   27.2000  426.0  704.500000       0.004757          1
# ...           ...       ...    ...         ...            ...        ...
# 8139        21.05   36.0975  433.0  787.250000       0.005579          1
# 8140        21.05   35.9950  433.0  789.500000       0.005563          1
# 8141        21.10   36.0950  433.0  798.500000       0.005596          1
# 8142        21.10   36.2600  433.0  820.333333       0.005621          1
# 8143        21.10   36.2000  447.0  821.000000       0.005612          1
#
# [8143 rows x 6 columns]

# %%
df = df.astype('float32')

# %%
df
# Out:
#       Temperature   Humidity  Light         CO2  HumidityRatio  Occupancy
# 1       23.180000  27.271999  426.0  721.250000       0.004793        1.0
# 2       23.150000  27.267500  429.5  714.000000       0.004783        1.0
# 3       23.150000  27.245001  426.0  713.500000       0.004779        1.0
# 4       23.150000  27.200001  426.0  708.250000       0.004772        1.0
# 5       23.100000  27.200001  426.0  704.500000       0.004757        1.0
# ...           ...        ...    ...         ...            ...        ...
# 8139    21.049999  36.097500  433.0  787.250000       0.005579        1.0
# 8140    21.049999  35.994999  433.0  789.500000       0.005563        1.0
# 8141    21.100000  36.095001  433.0  798.500000       0.005596        1.0
# 8142    21.100000  36.259998  433.0  820.333313       0.005621        1.0
# 8143    21.100000  36.200001  447.0  821.000000       0.005612        1.0
#
# [8143 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8143 entries, 1 to 8143
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Temperature    8143 non-null   float32
#  1   Humidity       8143 non-null   float32
#  2   Light          8143 non-null   float32
#  3   CO2            8143 non-null   float32
#  4   HumidityRatio  8143 non-null   float32
#  5   Occupancy      8143 non-null   float32
# dtypes: float32(6)
# memory usage: 254.5 KB

# %%
df.isna().sum()
# Out:
# Temperature      0
# Humidity         0
# Light            0
# CO2              0
# HumidityRatio    0
# Occupancy        0
# dtype: int64

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize = 15)
        
    plotnumber += 1
    
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['Occupancy'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['Humidity'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['HumidityRatio'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['Temperature'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['Light'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20, 15))
plotnumber = 1

for column in df:
    if plotnumber <= 14:
        ax = plt.subplot(3, 5, plotnumber)
        sns.scatterplot(x = df['CO2'], y = df[column])
        
    plotnumber += 1

plt.tight_layout()
plt.show()

# %%
X = df.drop(columns = 'Occupancy', axis = 1)
y = df['Occupancy']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[2.51847   , 0.27852607, 1.5737628 , 0.3649481 , 1.0917572 ],
#        [2.4889667 , 0.27771255, 1.5917351 , 0.34188107, 1.0805548 ],
#        [2.4889667 , 0.27364463, 1.5737628 , 0.34029025, 1.0758883 ],
#        ...,
#        [0.4729455 , 1.8737543 , 1.6097075 , 0.6107311 , 2.033527  ],
#        [0.4729455 , 1.9035863 , 1.6097075 , 0.68019724, 2.063811  ],
#        [0.4729455 , 1.8927386 , 1.6815968 , 0.6823184 , 2.0527985 ]],
#       dtype=float32)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.30, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
lr.score(X_test, y_test)
# Out:
# 0.8474594248172562

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso, LassoCV

lasso_cv = LassoCV(alphas = None, cv = 10, max_iter = 100000, normalize = True)
lasso_cv.fit(X_train, y_train)
# Out:
# LassoCV(cv=10, max_iter=100000, normalize=True)

# %%
alpha = lasso_cv.alpha_  #best alpha parameter
alpha
# Out:
# 4.915966903954219e-06

# %%
lasso = Lasso(alpha = lasso_cv.alpha_)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=4.915966903954219e-06)

# %%
lasso.score(X_test, y_test)
# Out:
# 0.8471861653658571
